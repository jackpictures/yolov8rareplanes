# %%
# !python train.py --img 512 --batch 64 --epochs 100 --device 0 --data ./data/class_one.yaml --cfg ./models/yolov5l.yaml --weights '' --name yolov5l_rareplanes

# %%
# !mv ./runs/exp0_yolov5l_rareplanes ./runs/class_one_yolov5l
yolo task=detect mode=train --imgsz=512 --batch=64 --epochs=100 --device 0 --data ./data/class_one.yaml --name=yolo5class22222 lr=0.001 optimizer=Adam
# Out:
#   Cell In[45], line 2
#     yolo task=detect mode=train --imgsz=512 --batch=18 --epochs=100 --device 0 --data ./data/class_one.yaml --name=yolo5class2 lr=0.001 optimizer=Adam
#          ^
# SyntaxError: invalid syntax

# %%
import torch
a=torch.cuda.FloatTensor()
a
# Out:
# tensor([], device='cuda:0')

# %%
from os import listdir
from os.path import isfile, join
mypath = r'C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\test images'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
for i in range(len(onlyfiles)):
    onlyfiles[i] = join(mypath,onlyfiles[i])
onlyfiles
# Out:
# ['C:\\Users\\Professional\\Desktop\\test1\\rareplanes-yolo-main\\test images\\1234.PNG',
#  'C:\\Users\\Professional\\Desktop\\test1\\rareplanes-yolo-main\\test images\\12345.PNG',
#  'C:\\Users\\Professional\\Desktop\\test1\\rareplanes-yolo-main\\test images\\1461329301_ramstein-air-base.jpg',
#  'C:\\Users\\Professional\\Desktop\\test1\\rareplanes-yolo-main\\test images\\1461329309_spangdahlem-air-base.jpg',
#  'C:\\Users\\Professional\\Desktop\\test1\\rareplanes-yolo-main\\test images\\1461329478_gaylenkirhen-drlo-e-3d.jpg',
#  'C:\\Users\\Professional\\Desktop\\test1\\rareplanes-yolo-main\\test images\\1461329676_b-52.jpg',
#  'C:\\Users\\Professional\\Desktop\\test1\\rareplanes-yolo-main\\test images\\1461329696_leykenhit.jpg',
#  'C:\\Users\\Professional\\Desktop\\test1\\rareplanes-yolo-main\\test images\\1461329822_uoddington.jpg',
#  'C:\\Users\\Professional\\Desktop\\test1\\rareplanes-yolo-main\\test images\\1461330084_oae.jpg',
# ...

# %%
import cv2
images = [cv2.imread(x) for x in onlyfiles]
imgsz = [x.shape[:-1] for x in images]
imgsz
# Out:
# [(439, 637),
#  (756, 1534),
#  (698, 1280),
#  (698, 1280),
#  (698, 1280),
#  (698, 1280),
#  (698, 1280),
#  (698, 1280),
#  (698, 1280),
#  (698, 1280),
#  (698, 1280),
#  (621, 1280),
#  (509, 800),
#  (869, 943),
#  (700, 1600),
#  (320, 480),
#  (497, 600),
#  (780, 1536),
#  (1267, 1881),
#  (378, 708),
#  (1581, 2786)]

# %%
from ultralytics import YOLO
import cv2
model = YOLO(r'C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\runs\detect\yolo8_2classes\weights\best.pt')

# %%
imagepath = r'C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\satellite predict images\armavir1.PNG'
results = model(imagepath,verbose = True,scale = 1, save=True,line_thickness=1,conf = 0.82,task= 'detect',imgsz = 1024)
# Out:
# image 1/1 C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\satellite predict images\armavir1.png: 576x1024 6 jets, 170.1ms
# Speed: 4.0ms preprocess, 170.1ms inference, 3.0ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to runs\detect\predict101
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 results = model(imagepath,verbose = True,scale = 1, save=True,line_thickness=1,conf = 0.82,task= 'detect',imgsz = 1024)
#       3 results[0].plot()
# ----> 4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
img = results[0].plot()
img
# Out:
# array([[[ 61,  70,  53],
#         [ 60,  70,  51],
#         [ 59,  70,  50],
#         ...,
#         [ 60,  85,  49],
#         [ 61,  85,  49],
#         [ 63,  85,  49]],
#
#        [[ 59,  68,  51],
#         [ 61,  72,  53],
#         [ 65,  77,  57],
#         ...,
#         [ 58,  84,  49],
#         [ 58,  84,  49],
#         [ 59,  84,  49]],
#
#        [[ 74,  82,  66],
#         [ 85,  95,  77],
#         [ 93, 104,  85],
#         ...,
#         [ 57,  83,  49],
#         [ 57,  82,  49],
#         [ 57,  82,  49]],
#
#        ...,
#
#        [[ 62,  83,  54],
#         [ 61,  83,  54],
#         [ 58,  81,  56],
#         ...,
#         [ 24,  25,  16],
#         [ 14,  11,   6],
#         [  5,   3,   0]],
#
#        [[ 61,  83,  53],
#         [ 63,  83,  54],
#         [ 62,  84,  56],
#         ...,
#         [ 15,  15,   7],
#         [ 10,   6,   2],
#         [  7,   3,   0]],
#
#        [[ 61,  83,  53],
#         [ 63,  83,  54],
#         [ 64,  84,  56],
# ...

# %%
from os import listdir
from os.path import isfile, join
import cv2
from ultralytics import YOLO

mypath = r'C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\satellite predict images' #путь к папке с изображениями
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))] #формирование списка изображений
for i in range(len(onlyfiles)):
    onlyfiles[i] = join(mypath,onlyfiles[i])
images = [cv2.imread(x) for x in onlyfiles]

img_sizes = [x.shape[:-1] for x in images]  # Список размеров каждого изображения

model = YOLO(r'C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\runs\detect\yolo8_2classes\weights\best.pt')
for i,j in zip(onlyfiles,img_sizes):
    predict_image = model(i, verbose=True, scale=1, save=True, line_thickness=1, conf=0.7, task='detect', imgsz=j)
# Out:
# WARNING  imgsz=[638, 1074] must be multiple of max stride 32, updating to [640, 1088]
# image 1/1 C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\satellite predict images\2023-04-04 151801.png: 640x1088 1 jet, 1 propeller, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 1088)
# Results saved to runs\detect\predict98
#
# WARNING  imgsz=[416, 855] must be multiple of max stride 32, updating to [416, 864]
# image 1/1 C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\satellite predict images\antonov.png: 416x864 4 jets, 8 propellers, 123.7ms
# Speed: 1.0ms preprocess, 123.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 864)
# Results saved to runs\detect\predict98
#
# WARNING  imgsz=[837, 1361] must be multiple of max stride 32, updating to [864, 1376]
# image 1/1 C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\satellite predict images\antonov2.png: 864x1376 1 jet, 3 propellers, 128.7ms
# ...

# %%
predict_image = model(r"C:\Users\Professional\Videos\Desktop\Desktop 2023.05.20 - 18.46.30.02.mp4", verbose=True, scale=1, save=True, line_thickness=1, conf=0.1, task='detect',imgsz = [1920,1080])
# Out:
# WARNING  imgsz=[1920, 1080] must be multiple of max stride 32, updating to [1920, 1088]
# video 1/1 (1/337) C:\Users\Professional\Videos\Desktop\Desktop 2023.05.20 - 18.46.30.02.mp4: 640x1088 4 propellers, 7.0ms
# video 1/1 (2/337) C:\Users\Professional\Videos\Desktop\Desktop 2023.05.20 - 18.46.30.02.mp4: 640x1088 4 propellers, 7.0ms
# video 1/1 (3/337) C:\Users\Professional\Videos\Desktop\Desktop 2023.05.20 - 18.46.30.02.mp4: 640x1088 4 propellers, 7.0ms
# video 1/1 (4/337) C:\Users\Professional\Videos\Desktop\Desktop 2023.05.20 - 18.46.30.02.mp4: 640x1088 5 propellers, 8.0ms
# video 1/1 (5/337) C:\Users\Professional\Videos\Desktop\Desktop 2023.05.20 - 18.46.30.02.mp4: 640x1088 4 propellers, 7.0ms
# video 1/1 (6/337) C:\Users\Professional\Videos\Desktop\Desktop 2023.05.20 - 18.46.30.02.mp4: 640x1088 4 propellers, 7.0ms
# video 1/1 (7/337) C:\Users\Professional\Videos\Desktop\Desktop 2023.05.20 - 18.46.30.02.mp4: 640x1088 3 propellers, 7.0ms
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from torch import mask_rcnn
#       3 # Загрузка изображения
#       4
#       5 # Загрузка модели Mask R-CNN
#       6 model = mask_rcnn
#
# ImportError: cannot import name 'mask_rcnn' from 'torch' (c:\Python11\Lib\site-packages\torch\__init__.py)

# %%
# !yolo task=detect mode=train imgsz=512 batch=64 epochs=100 device=0 verbose=True name=yolo8classes2 
 lr0=0.001 lrf=0.01 iou = 0.7 optimizer=Adam data=C:\Users\Professional\Desktop\test1\rareplanes-yolo-main\data\class_one.yaml
# Out:
# ^C

# %%
# !yolo task=detect mode=predict model=C:/Users/Professional/Desktop/test1/rareplanes-yolo-main/runs/detect/yolo8_2classes/weights/best.pt --imgsz=512 --conf=0.4 source=C:/Users/Professional/yoloplanes/class_one/images/val save_txt=True
# Out:
# WARNING  '--imgsz=512' does not require leading dashes '--', updating to 'imgsz=512'.
# WARNING  '--conf=0.4' does not require leading dashes '--', updating to 'conf=0.4'.
# Ultralytics YOLOv8.0.55  Python-3.11.2 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/2710 C:\Users\Professional\yoloplanes\class_one\images\val\105_104001003108D900_tile_47.png: 512x512 1 propeller, 8.0ms
# image 2/2710 C:\Users\Professional\yoloplanes\class_one\images\val\105_104001003108D900_tile_51.png: 512x512 3 propellers, 6.0ms
# image 3/2710 C:\Users\Professional\yoloplanes\class_one\images\val\105_104001003108D900_tile_53.png: 512x512 4 propellers, 6.0ms
# image 4/2710 C:\Users\Professional\yoloplanes\class_one\images\val\105_104001003108D900_tile_55.png: 512x512 2 propellers, 6.0ms
# ...

# %%
# !mv ./inference/output ./inference/class_one_out

# %%
# !python test.py --weights ./runs/class_one_yolov5l/weights/best_yolov5l_rareplanes.pt --data ./data/class_one.yaml --img 512 --verbose --conf-thres 0.4

# %%
# !yolo task=detect mode=val 
model=C:/Users/Professional/Desktop/test1/rareplanes-yolo-main/runs/detect/yolo8_2classes/weights/best.pt
 --imgsz=512 --conf=0.4 data=./data/class_one.yaml
# Out:
# WARNING  '--imgsz=512' does not require leading dashes '--', updating to 'imgsz=512'.
# WARNING  '--conf=0.4' does not require leading dashes '--', updating to 'conf=0.4'.
# Ultralytics YOLOv8.0.55  Python-3.11.2 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# val: Scanning C:\Users\Professional\yoloplanes\class_one\labels\val.cache... 2710 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2710/2710 [00:00<?, ?it/s]
# val: Scanning C:\Users\Professional\yoloplanes\class_one\labels\val.cache... 2710 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2710/2710 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/170 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   1%|          | 1/170 [00:22<1:02:52, 22.32s/it]
# ...
